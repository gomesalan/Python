# %% [markdown]
# ## Módulos e Pacotes

# %% [markdown]
# ### 1 - Módulos
#
# Os módulos são arquivos python que contém um conjunto de funções para serem implementadas.
#
# Módulos podem ser criados: 'meu_arquivo'.py
# E carregados: import 'meu_arquivo'

# %%
# O arquivo modulo_teste.py está salvo no mesmo diretório do jupyter.

import modulo_teste 
lista1 = [1, 2, 3, 4, 5, 6]
mediana(lista1)

# %% [markdown]
# ### 2 - Pacotes

# %% [markdown]
# Os pacotes são conjuntos de módulos, para instalá-los utiliza-se os seguintes comandos no cmd:
#
#     pip install 'nome do pacote'
#
# Pode-se instalar via Jupyter notebook acrescentando o caractere "!" -
#
#     !pip install 'nome do pacote'

# %%
# Importando um pacote em Python, exemplo pacote de matemática - math

import math

# %%
# Para verificar todos os métodos e funções do pacote.

print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc']

# %% [markdown]
# ### 3 - Tratamento de erros e excessões

# %%
# Este comando resultará em erro. 

dividendo = 10
divisor = 0 

quociente = dividendo // divisor

# %% [markdown]
# #### 3.1) Try/Except

# %%
# Usando try/except:

dividendo = 10
divisor = 0 

try:
    quociente = dividendo // divisor # Caso este comando resulte em erro, o comando logo após except é executado
except:
    print("Divisor igual a 0 !!!")
    
# Obs: altere o divisor para 1..
# Out:
# Divisor igual a 0 !!!
